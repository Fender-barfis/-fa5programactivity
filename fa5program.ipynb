# %% [markdown]
# <a href="https://colab.research.google.com/github/Fender-barfis/-fa5programactivity/blob/THE-BRANCH/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total

print(" Welcome to your Calculator ")

try:
    user_price = float(input("Enter the price of the item: "))
    user_quantity = int(input("Enter the number of items: "))

    final_price = calculate_total(user_price, user_quantity)

    print(f"\nTotal Price: ${final_price:.2f}")

except ValueError:
    print("Invalid input! Please enter numbers only.")
# Out:
#  Welcome to your Calculator
# Enter the price of the item: 2
# Enter the number of items: 682468
#
# Total Price: $1364936.00
